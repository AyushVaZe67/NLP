# %%
import numpy as np
import spacy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 import numpy as np
# ----> 2 import spacy
#
# ModuleNotFoundError: No module named 'spacy'

# %%
pip install spacy==3.6.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.1 MB 799.2 kB/s eta 0:00:15
#    - -------------------------------------- 0.5/12.1 MB 799.2 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/12.1 MB 932.9 kB/s eta 0:00:13
#    --- ------------------------------------ 1.0/12.1 MB 986.7 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/12.1 MB 958.5 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.6/12.1 MB 1.0 MB/s eta 0:00:11
#    ------ --------------------------------- 1.8/12.1 MB 1.0 MB/s eta 0:00:10
# ...

# %%
conda install -c conda-forge spacy

# %%
nlp = space.load('en_core_web_sm')

# %%
doc = nlp.
